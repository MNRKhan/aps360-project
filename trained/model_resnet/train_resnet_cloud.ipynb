# %%
# !wget https://github.com/MNRKhan/aps360-project/raw/master/modules/cleaning.py
# !wget https://github.com/MNRKhan/aps360-project/raw/master/modules/data_loader.py
# !wget https://github.com/MNRKhan/aps360-project/raw/master/modules/extractNet_resnet.py 
# !wget https://github.com/MNRKhan/aps360-project/raw/master/modules/extractNet_resnet_prelu.py   
# !wget https://github.com/MNRKhan/aps360-project/raw/master/modules/helper.py
# !wget https://github.com/MNRKhan/aps360-project/raw/master/modules/metrics.py
# !wget https://github.com/MNRKhan/aps360-project/raw/master/modules/trainer.py
# !wget https://github.com/MNRKhan/aps360-project/raw/master/modules/visualizer.py
# !wget https://github.com/MNRKhan/aps360-project/raw/master/modules/extractNet_connected_vgg19_bn.py 
# !wget https://github.com/MNRKhan/aps360-project/raw/master/modules/model_blocks.py
# Out:
# --2019-03-30 02:39:51--  https://github.com/MNRKhan/aps360-project/raw/master/modules/cleaning.py
# Resolving github.com (github.com)... 192.30.253.112, 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/MNRKhan/aps360-project/master/modules/cleaning.py [following]
# --2019-03-30 02:39:52--  https://raw.githubusercontent.com/MNRKhan/aps360-project/master/modules/cleaning.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8263 (8.1K) [text/plain]
# Saving to: ‘cleaning.py.2’
#
# cleaning.py.2       100%[===================>]   8.07K  --.-KB/s    in 0s
#
# ...

# %%
import numpy as np
import random
import torch
from torch.utils.data import DataLoader
from torchvision import transforms

#from cleaning import *
from data_loader import *
from model_blocks import *
from extractNet_resnet import *
from extractNet_resnet_prelu import *
from extractNet_connected_vgg19_bn import *
from helper import *
from metrics import *
from trainer import *
from visualizer import *

# %%
# !rm -rf __MACOSX
# !rm -rf *.zip
# !wget https://github.com/MNRKhan/aps360-project/raw/master/datasets/train2014/data_person_vehicle.zip
# !unzip data_person_vehicle.zip
# !rm -rf __MACOSX
# !rm -rf *.zip
# Out:
# --2019-03-30 02:41:33--  https://github.com/MNRKhan/aps360-project/raw/master/datasets/train2014/data_person_vehicle.zip
# Resolving github.com (github.com)... 192.30.253.112, 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/MNRKhan/aps360-project/master/datasets/train2014/data_person_vehicle.zip [following]
# --2019-03-30 02:41:34--  https://media.githubusercontent.com/media/MNRKhan/aps360-project/master/datasets/train2014/data_person_vehicle.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 141567675 (135M) [application/zip]
# Saving to: ‘data_person_vehicle.zip’
#
# ...

# %%
batch_size = 64
lr = 0.001

# %%
# Set random seeds
torch.manual_seed(360)
np.random.seed(360)
random.seed(360)

# Form dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
dataset = ImageMaskDataset("/home/hasanmohsin19/data", transform)

# Dataset sizes
size = len(dataset)
train_size = int(0.6 * size)
valid_size = int(0.2 * size)
test_size = size - train_size - valid_size

batch_size = 64

# Splitting datasets
train_data, valid_data, test_data = torch.utils.data.random_split(dataset, [train_size, valid_size, test_size])

#train_data = train_data[:3999]
#valid_data = valid_data[:199]

# Making dataloader
train = DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=True)
valid = DataLoader(valid_data, batch_size=batch_size, shuffle=True, num_workers=0)

# %%
print("Training size: ", train_size)
print("Validation size: ", valid_size)
# Out:
# Training size:  5950
# Validation size:  1983

# %%
print("Full data set: ", size)
# Out:
# Full data set:  9917

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
full_model = extractNet_resnet_prelu()
full_model.to(device)
# Out:
# extractNet_resnet_prelu(
#   (res): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
# ...

# %%
# Train 
trainModel(full_model, train, valid, batch_size=batch_size, lr=lr, num_epochs=80, checkpoint=False, device=device)
# Out:
# Epoch:0, Train IoU:0.6400, Train Loss:0.0095|Valid IoU:0.6381, Valid Loss:0.0095
# Epoch:1, Train IoU:0.6937, Train Loss:0.0092|Valid IoU:0.6850, Valid Loss:0.0093
# Epoch:2, Train IoU:0.7261, Train Loss:0.0091|Valid IoU:0.7110, Valid Loss:0.0092
# Epoch:3, Train IoU:0.7392, Train Loss:0.0089|Valid IoU:0.7163, Valid Loss:0.0091
# Epoch:4, Train IoU:0.7608, Train Loss:0.0090|Valid IoU:0.7347, Valid Loss:0.0091
# Epoch:5, Train IoU:0.7922, Train Loss:0.0089|Valid IoU:0.7557, Valid Loss:0.0091
# Epoch:6, Train IoU:0.8205, Train Loss:0.0087|Valid IoU:0.7737, Valid Loss:0.0089
# Epoch:7, Train IoU:0.8367, Train Loss:0.0086|Valid IoU:0.7826, Valid Loss:0.0089
# Epoch:8, Train IoU:0.8431, Train Loss:0.0086|Valid IoU:0.7813, Valid Loss:0.0089
# Epoch:9, Train IoU:0.8665, Train Loss:0.0086|Valid IoU:0.7984, Valid Loss:0.0089
# Epoch:10, Train IoU:0.8810, Train Loss:0.0085|Valid IoU:0.8026, Valid Loss:0.0089
# ---------------------------------------------------------------------------
# ...

# %%
full = extractNet_resnet_prelu()
full.to(device)
# Out:
# extractNet_resnet_prelu(
#   (res): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
# ...

# %%
# Train 
trainModel(full, train, valid, batch_size=batch_size, lr=lr, num_epochs=80, checkpoint=False, device=device)
# Out:
# Epoch:0, Train IoU:0.6469, Train Loss:0.0095|Valid IoU:0.6446, Valid Loss:0.0095
# Epoch:1, Train IoU:0.6987, Train Loss:0.0093|Valid IoU:0.6900, Valid Loss:0.0093
# Epoch:2, Train IoU:0.7232, Train Loss:0.0092|Valid IoU:0.7091, Valid Loss:0.0092
# Epoch:3, Train IoU:0.7376, Train Loss:0.0090|Valid IoU:0.7151, Valid Loss:0.0091
# Epoch:4, Train IoU:0.7689, Train Loss:0.0090|Valid IoU:0.7410, Valid Loss:0.0091
# Epoch:5, Train IoU:0.7944, Train Loss:0.0089|Valid IoU:0.7583, Valid Loss:0.0091
# Epoch:6, Train IoU:0.8208, Train Loss:0.0087|Valid IoU:0.7747, Valid Loss:0.0090
# Epoch:7, Train IoU:0.8351, Train Loss:0.0086|Valid IoU:0.7813, Valid Loss:0.0089
# Epoch:8, Train IoU:0.8429, Train Loss:0.0086|Valid IoU:0.7826, Valid Loss:0.0089
# Epoch:9, Train IoU:0.8624, Train Loss:0.0086|Valid IoU:0.7959, Valid Loss:0.0089
# Epoch:10, Train IoU:0.8792, Train Loss:0.0085|Valid IoU:0.8007, Valid Loss:0.0089
# Epoch:11, Train IoU:0.8723, Train Loss:0.0084|Valid IoU:0.7873, Valid Loss:0.0088
# ...

# %%
full = full.eval()
full.to("cpu")
torch.save(full.state_dict(), "full_weights_cpu")
f_state = torch.load("full_weights_cpu")

# %%
# !wget https://github.com/MNRKhan/aps360-project/raw/master/modules/saving_pretrain.py
# Out:
# --2019-03-30 06:37:24--  https://github.com/MNRKhan/aps360-project/raw/master/modules/saving_pretrain.py
# Resolving github.com (github.com)... 192.30.253.112, 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/MNRKhan/aps360-project/master/modules/saving_pretrain.py [following]
# --2019-03-30 06:37:25--  https://raw.githubusercontent.com/MNRKhan/aps360-project/master/modules/saving_pretrain.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 758 [text/plain]
# Saving to: ‘saving_pretrain.py.1’
#
# saving_pretrain.py. 100%[===================>]     758  --.-KB/s    in 0s
#
# ...

# %%
from saving_pretrain import *

# %%
my_state = get_dc_state(f_state)
torch.save(my_state, "full_weights_dc_cpu")

# %%
state_ = torch.load("full_weights_cpu")
full_check = extractNet_resnet_prelu()
full_check.load_state_dict(state_)

# %%
full_check = extractNet_resnet_prelu()
path = "full_weights_dc"
full_check = load_state_from_dc(full_check, path)

# %%
full_check.to("cpu")

# After training (train set)
img, target = train_data[-112]
target = target.squeeze(0).detach().numpy()
out = torch.sigmoid(full_check(img.unsqueeze(0)))
out = out.squeeze(0).squeeze(0).detach().numpy()
out = thresholdProbMask(out)
denoised = denoise(out)

imshow(np.transpose(img.squeeze(0).detach().numpy(), [1,2,0]))
imshow(target)
imshow(out)
imshow(denoised)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Given a model and dataset of (image, mask) tuples, calculate overall IoU
def calculateTotalIoUTest(model, data_loader, device=None):

    total_iou = 0
    num_data = 0

    for i, batch in enumerate(data_loader):
        img, target = batch



        pred = torch.sigmoid(model(img))
        iou = calculateIoU(pred, target)

        total_iou += iou
        num_data += img.shape[0]

    # Average IoU on data set  
    return total_iou/num_data


# Computes average loss over dataset
def getLossTest(model, data_loader, criterion, device=None):

    total_loss = 0
    num_data = 0

    for i, batch in enumerate(data_loader):
        img, target = batch


        pred = torch.sigmoid(model(img))
        loss = criterion(pred, target)

        total_loss += loss
        num_data += img.shape[0]

    return total_loss/num_data

# %%
test = DataLoader(test_data, batch_size=batch_size, shuffle=True, num_workers=0)

# %%
#test accuracy
criterion = torch.nn.BCEWithLogitsLoss()
full.to("cpu")

with torch.no_grad():
    test_acc = calculateTotalIoUTest(full.eval(), test)
    print("Test IoU: ", test_acc)
    test_loss = getLossTest(full.eval(), test, criterion)
    print("Test Loss: ", test_loss)
# Out:
# Test IoU:  0.8420393947632082
# Test Loss:  tensor(0.0088)

# %%
print("Test Loss: ", test_loss)
print("Test IoU: ", test_acc)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net = extractNet_resnet_prelu()
net.to(device)

print("Model is being trained on:", device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /home/hasanmohsin19/.torch/models/resnet50-19c8e357.pth
# 102502400it [00:01, 81584449.52it/s]
# Model is being trained on: cuda:0

# %%
torch.cuda.empty_cache()

# %%
print(net)
# Out:
# extractNet_resnet(
#   (res): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
# ...

# %%
# Train 
trainModel(net, train, valid, batch_size=batch_size, lr=lr, num_epochs=80, checkpoint=False, device=device)
# Out:
# Epoch:0, Train IoU:0.3314, Train Loss:0.0117|Valid IoU:0.3309, Valid Loss:0.0147
# Epoch:1, Train IoU:0.3485, Train Loss:0.0114|Valid IoU:0.3479, Valid Loss:0.0145
# Epoch:2, Train IoU:0.3961, Train Loss:0.0110|Valid IoU:0.3927, Valid Loss:0.0141
# Epoch:3, Train IoU:0.4878, Train Loss:0.0104|Valid IoU:0.4776, Valid Loss:0.0134
# Epoch:4, Train IoU:0.5766, Train Loss:0.0100|Valid IoU:0.5586, Valid Loss:0.0127
# Epoch:5, Train IoU:0.5745, Train Loss:0.0097|Valid IoU:0.5507, Valid Loss:0.0126
# Epoch:6, Train IoU:0.6262, Train Loss:0.0099|Valid IoU:0.5997, Valid Loss:0.0129
# Epoch:7, Train IoU:0.6313, Train Loss:0.0095|Valid IoU:0.5955, Valid Loss:0.0123
# Epoch:8, Train IoU:0.6391, Train Loss:0.0094|Valid IoU:0.5979, Valid Loss:0.0125
# Epoch:9, Train IoU:0.6887, Train Loss:0.0092|Valid IoU:0.6347, Valid Loss:0.0124
# Epoch:10, Train IoU:0.7100, Train Loss:0.0091|Valid IoU:0.6440, Valid Loss:0.0122
# Epoch:11, Train IoU:0.7345, Train Loss:0.0092|Valid IoU:0.6649, Valid Loss:0.0124
# ...

# %%
torch.save(net.state_dict(), "resnet50_weights")

# %%
net_152 = extractNet_resnet_prelu(r_size=152)
net_152.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to /home/hasanmohsin19/.torch/models/resnet152-b121ed2d.pth
# 241530880it [00:03, 70810265.79it/s]
# extractNet_resnet_prelu(
#   (res): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
trainModel(net_152, train, valid, batch_size=batch_size, lr=lr, num_epochs=80, checkpoint=False, device=device)
# Out:
# Epoch:0, Train IoU:0.3013, Train Loss:0.0112|Valid IoU:0.2989, Valid Loss:0.0144
# Epoch:1, Train IoU:0.3884, Train Loss:0.0108|Valid IoU:0.3883, Valid Loss:0.0138
# Epoch:2, Train IoU:0.4900, Train Loss:0.0100|Valid IoU:0.4819, Valid Loss:0.0129
# Epoch:3, Train IoU:0.5845, Train Loss:0.0098|Valid IoU:0.5622, Valid Loss:0.0128
# Epoch:4, Train IoU:0.6224, Train Loss:0.0096|Valid IoU:0.5962, Valid Loss:0.0123
# Epoch:5, Train IoU:0.5964, Train Loss:0.0095|Valid IoU:0.5696, Valid Loss:0.0125
# Epoch:6, Train IoU:0.6054, Train Loss:0.0095|Valid IoU:0.5706, Valid Loss:0.0123
# Epoch:7, Train IoU:0.6623, Train Loss:0.0095|Valid IoU:0.6220, Valid Loss:0.0123
# Epoch:8, Train IoU:0.6853, Train Loss:0.0095|Valid IoU:0.6432, Valid Loss:0.0126
# Epoch:9, Train IoU:0.7138, Train Loss:0.0091|Valid IoU:0.6565, Valid Loss:0.0120
# Epoch:10, Train IoU:0.7265, Train Loss:0.0090|Valid IoU:0.6586, Valid Loss:0.0120
# Epoch:11, Train IoU:0.7540, Train Loss:0.0090|Valid IoU:0.6724, Valid Loss:0.0121
# ...

# %%
torch.save(net.state_dict(), "resnet152_weights")

# %%
net_p = extractNet_resnet_prelu('P')
net_p.to(device)
# Out:
# extractNet_resnet_prelu(
#   (res): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
# ...

# %%
trainModel(net_p, train, valid, batch_size=batch_size, lr=lr, num_epochs=80, checkpoint=False, device=device)
# Out:
# Epoch:0, Train IoU:0.3850, Train Loss:0.0115|Valid IoU:0.3856, Valid Loss:0.0146
# Epoch:1, Train IoU:0.3884, Train Loss:0.0110|Valid IoU:0.3883, Valid Loss:0.0142
# Epoch:2, Train IoU:0.3277, Train Loss:0.0106|Valid IoU:0.3231, Valid Loss:0.0137
# Epoch:3, Train IoU:0.5443, Train Loss:0.0104|Valid IoU:0.5455, Valid Loss:0.0134
# Epoch:4, Train IoU:0.5528, Train Loss:0.0098|Valid IoU:0.5468, Valid Loss:0.0125
# Epoch:5, Train IoU:0.5587, Train Loss:0.0100|Valid IoU:0.5524, Valid Loss:0.0129
# Epoch:6, Train IoU:0.5574, Train Loss:0.0099|Valid IoU:0.5482, Valid Loss:0.0127
# Epoch:7, Train IoU:0.5858, Train Loss:0.0098|Valid IoU:0.5734, Valid Loss:0.0126
# Epoch:8, Train IoU:0.5988, Train Loss:0.0095|Valid IoU:0.5765, Valid Loss:0.0122
# Epoch:9, Train IoU:0.6350, Train Loss:0.0097|Valid IoU:0.6149, Valid Loss:0.0125
# Epoch:10, Train IoU:0.6355, Train Loss:0.0096|Valid IoU:0.6118, Valid Loss:0.0122
# Epoch:11, Train IoU:0.6537, Train Loss:0.0095|Valid IoU:0.6246, Valid Loss:0.0124
# ...

# %%
torch.save(net_p.state_dict(), "resnet50-p_weights")

# %%
trainModel(net_p, train, valid, batch_size=batch_size, lr=lr, num_epochs=80, checkpoint=False, device=device)
# Out:
# Epoch:0, Train IoU:0.6228, Train Loss:0.0102|Valid IoU:0.5959, Valid Loss:0.0134
# Epoch:1, Train IoU:0.6406, Train Loss:0.0098|Valid IoU:0.6139, Valid Loss:0.0127
# Epoch:2, Train IoU:0.6445, Train Loss:0.0093|Valid IoU:0.5999, Valid Loss:0.0121
# Epoch:3, Train IoU:0.6643, Train Loss:0.0092|Valid IoU:0.6073, Valid Loss:0.0121
# Epoch:4, Train IoU:0.7101, Train Loss:0.0093|Valid IoU:0.6538, Valid Loss:0.0123
# Epoch:5, Train IoU:0.7094, Train Loss:0.0091|Valid IoU:0.6352, Valid Loss:0.0121
# Epoch:6, Train IoU:0.6663, Train Loss:0.0092|Valid IoU:0.5893, Valid Loss:0.0122
# Epoch:7, Train IoU:0.7481, Train Loss:0.0091|Valid IoU:0.6762, Valid Loss:0.0122
# Epoch:8, Train IoU:0.7737, Train Loss:0.0088|Valid IoU:0.6687, Valid Loss:0.0121
# Epoch:9, Train IoU:0.7805, Train Loss:0.0088|Valid IoU:0.6590, Valid Loss:0.0119
# Epoch:10, Train IoU:0.6805, Train Loss:0.0092|Valid IoU:0.6039, Valid Loss:0.0124
# Epoch:11, Train IoU:0.7498, Train Loss:0.0091|Valid IoU:0.6702, Valid Loss:0.0123
# ...

# %%
net_bn2 = extractNet_resnet_prelu(act_type = 'P')
net_bn2.to(device)
# Out:
# extractNet_resnet_prelu(
#   (res): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
# ...

# %%
trainModel(net_bn2, train, valid, batch_size=batch_size, lr=lr, num_epochs=200, checkpoint=False, device=device)
# Out:
# Epoch:0, Train IoU:0.3435, Train Loss:0.0114|Valid IoU:0.3438, Valid Loss:0.0146
# Epoch:1, Train IoU:0.4568, Train Loss:0.0107|Valid IoU:0.4568, Valid Loss:0.0138
# Epoch:2, Train IoU:0.5673, Train Loss:0.0100|Valid IoU:0.5671, Valid Loss:0.0129
# Epoch:3, Train IoU:0.5979, Train Loss:0.0097|Valid IoU:0.5936, Valid Loss:0.0124
# Epoch:4, Train IoU:0.5840, Train Loss:0.0096|Valid IoU:0.5770, Valid Loss:0.0124
# Epoch:5, Train IoU:0.6152, Train Loss:0.0096|Valid IoU:0.6108, Valid Loss:0.0122
# Epoch:6, Train IoU:0.6452, Train Loss:0.0098|Valid IoU:0.6409, Valid Loss:0.0125
# Epoch:7, Train IoU:0.6246, Train Loss:0.0095|Valid IoU:0.6156, Valid Loss:0.0124
# Epoch:8, Train IoU:0.6321, Train Loss:0.0096|Valid IoU:0.6205, Valid Loss:0.0122
# Epoch:9, Train IoU:0.6689, Train Loss:0.0094|Valid IoU:0.6566, Valid Loss:0.0121
# Epoch:10, Train IoU:0.6856, Train Loss:0.0094|Valid IoU:0.6703, Valid Loss:0.0121
# Epoch:11, Train IoU:0.6203, Train Loss:0.0094|Valid IoU:0.6046, Valid Loss:0.0120
# ...

# %%
#compare to 
comp_net = extractNet_connected_vgg19_bn()
comp_net.to(device)
# Out:
# extractNet_connected_vgg19_bn(
#   (vgg): VGG(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace)
#       (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (9): ReLU(inplace)
#       (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (12): ReLU(inplace)
# ...

# %%
trainModel(comp_net, train, valid, batch_size=batch_size, lr=lr, num_epochs=70, checkpoint=True, device=device)
# Out:
# Epoch:0, Train IoU:0.2966, Train Loss:0.0116|Valid IoU:0.2987, Valid Loss:0.0154
# Epoch:1, Train IoU:0.2965, Train Loss:0.0115|Valid IoU:0.2956, Valid Loss:0.0153
# Epoch:2, Train IoU:0.3259, Train Loss:0.0114|Valid IoU:0.3221, Valid Loss:0.0152
# Epoch:3, Train IoU:0.3789, Train Loss:0.0108|Valid IoU:0.3654, Valid Loss:0.0146
# Epoch:4, Train IoU:0.4549, Train Loss:0.0107|Valid IoU:0.4356, Valid Loss:0.0146
# Epoch:5, Train IoU:0.4439, Train Loss:0.0098|Valid IoU:0.4064, Valid Loss:0.0134
# Epoch:6, Train IoU:0.5070, Train Loss:0.0101|Valid IoU:0.4691, Valid Loss:0.0140
# Epoch:7, Train IoU:0.5537, Train Loss:0.0098|Valid IoU:0.5022, Valid Loss:0.0136
# Epoch:8, Train IoU:0.5968, Train Loss:0.0095|Valid IoU:0.5312, Valid Loss:0.0132
# Epoch:9, Train IoU:0.6635, Train Loss:0.0095|Valid IoU:0.5827, Valid Loss:0.0134
# Epoch:10, Train IoU:0.6393, Train Loss:0.0093|Valid IoU:0.5604, Valid Loss:0.0129
# Epoch:11, Train IoU:0.6785, Train Loss:0.0095|Valid IoU:0.5964, Valid Loss:0.0134
# ...

# %%
#compare to without leaky relu
net2 = extractNet_connected_vgg19_bn_leaky(alpha=0.0)
net2.to(device)
# Out:
# extractNet_connected_vgg19_bn_leaky(
#   (vgg_feature): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace)
# ...

# %%
trainModel(net2, train, valid, batch_size=batch_size, lr=lr, num_epochs=70, checkpoint=False, device=device)
# Out:
# Epoch:0, Train IoU:0.3332, Train Loss:0.0116|Valid IoU:0.3337, Valid Loss:0.0155
# Epoch:1, Train IoU:0.3314, Train Loss:0.0113|Valid IoU:0.3253, Valid Loss:0.0152
# Epoch:2, Train IoU:0.4299, Train Loss:0.0104|Valid IoU:0.4042, Valid Loss:0.0143
# Epoch:3, Train IoU:0.5533, Train Loss:0.0105|Valid IoU:0.5155, Valid Loss:0.0146
# Epoch:4, Train IoU:0.5725, Train Loss:0.0098|Valid IoU:0.5154, Valid Loss:0.0136
# Epoch:5, Train IoU:0.5428, Train Loss:0.0100|Valid IoU:0.4960, Valid Loss:0.0138
# Epoch:6, Train IoU:0.5479, Train Loss:0.0096|Valid IoU:0.4893, Valid Loss:0.0133
# Epoch:7, Train IoU:0.6196, Train Loss:0.0096|Valid IoU:0.5550, Valid Loss:0.0135
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
# ...

# %%
#compare to without leaky relu
net3 = extractNet_connected_vgg19_bn_leaky(alpha=0.01)
net3.to(device)
# Out:
# extractNet_connected_vgg19_bn_leaky(
#   (vgg_feature): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace)
# ...

# %%
trainModel(net3, train, valid, batch_size=batch_size, lr=lr, num_epochs=70, checkpoint=False, device=device)
# Out:
# Epoch:0, Train IoU:0.3370, Train Loss:0.0115|Valid IoU:0.3375, Valid Loss:0.0154
# Epoch:1, Train IoU:0.3289, Train Loss:0.0115|Valid IoU:0.3263, Valid Loss:0.0153
# Epoch:2, Train IoU:0.3751, Train Loss:0.0112|Valid IoU:0.3639, Valid Loss:0.0151
# Epoch:3, Train IoU:0.4299, Train Loss:0.0108|Valid IoU:0.4038, Valid Loss:0.0147
# Epoch:4, Train IoU:0.4437, Train Loss:0.0105|Valid IoU:0.4133, Valid Loss:0.0143
# Epoch:5, Train IoU:0.5442, Train Loss:0.0101|Valid IoU:0.4969, Valid Loss:0.0139
# Epoch:6, Train IoU:0.5496, Train Loss:0.0098|Valid IoU:0.4885, Valid Loss:0.0134
# Epoch:7, Train IoU:0.6167, Train Loss:0.0098|Valid IoU:0.5523, Valid Loss:0.0137
# Epoch:8, Train IoU:0.5805, Train Loss:0.0095|Valid IoU:0.5057, Valid Loss:0.0132
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f66b2ef6898>>
# Traceback (most recent call last):
# ...

# %%
full.to("cpu")

# After training (train set)
img, target = train_data[-112]
target = target.squeeze(0).detach().numpy()
out = torch.sigmoid(full(img.unsqueeze(0)))
out = out.squeeze(0).squeeze(0).detach().numpy()
out = thresholdProbMask(out)
denoised = denoise(out)

imshow(np.transpose(img.squeeze(0).detach().numpy(), [1,2,0]))
imshow(target)
imshow(out)
imshow(denoised)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# After training (validation set)
img, target = valid_data[-2]
target = target.squeeze(0).detach().numpy()
out = torch.sigmoid(full(img.unsqueeze(0)))
out = out.squeeze(0).squeeze(0).detach().numpy()
out = thresholdProbMask(out)
denoised = denoise(out)


imshow(np.transpose(img.squeeze(0).detach().numpy(), [1,2,0]))
imshow(target)
imshow(out)
imshow(denoised)
imshow(np.expand_dims(denoised,axis=3)*np.transpose(img.squeeze(0).detach().numpy(), [1,2,0]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# !wget https://github.com/MNRKhan/aps360-project/raw/master/trained/model_connected_vgg_19_cloud/layers_epoch_300
# Out:
# --2019-03-30 00:33:26--  https://github.com/MNRKhan/aps360-project/raw/master/trained/model_connected_vgg_19_cloud/layers_epoch_300
# Resolving github.com (github.com)... 192.30.253.113, 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/MNRKhan/aps360-project/master/trained/model_connected_vgg_19_cloud/layers_epoch_300 [following]
# --2019-03-30 00:33:26--  https://raw.githubusercontent.com/MNRKhan/aps360-project/master/trained/model_connected_vgg_19_cloud/layers_epoch_300
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21843114 (21M) [application/octet-stream]
# Saving to: ‘layers_epoch_300’
#
# ...

# %%
# !wget https://github.com/MNRKhan/aps360-project/raw/master/modules/extractNet_connected_vgg19.py
# Out:
# --2019-03-30 00:19:47--  https://github.com/MNRKhan/aps360-project/raw/master/modules/extractNet_connected_vgg19.py
# Resolving github.com (github.com)... 192.30.253.112, 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/MNRKhan/aps360-project/master/modules/extractNet_connected_vgg19.py [following]
# --2019-03-30 00:19:47--  https://raw.githubusercontent.com/MNRKhan/aps360-project/master/modules/extractNet_connected_vgg19.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1805 (1.8K) [text/plain]
# Saving to: ‘extractNet_connected_vgg19.py’
#
# extractNet_connecte 100%[===================>]   1.76K  --.-KB/s    in 0s
# ...

# %%
# !wget https://github.com/MNRKhan/aps360-project/raw/master/modules/saving_pretrain.py
# Out:
# --2019-03-30 00:21:57--  https://github.com/MNRKhan/aps360-project/raw/master/modules/saving_pretrain.py
# Resolving github.com (github.com)... 192.30.253.112, 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/MNRKhan/aps360-project/master/modules/saving_pretrain.py [following]
# --2019-03-30 00:21:57--  https://raw.githubusercontent.com/MNRKhan/aps360-project/master/modules/saving_pretrain.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 758 [text/plain]
# Saving to: ‘saving_pretrain.py’
#
# saving_pretrain.py  100%[===================>]     758  --.-KB/s    in 0s
#
# ...

# %%
from extractNet_connected_vgg19 import *
from saving_pretrain import *

# %%
net_v = extractNet_connected_vgg19()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /home/hasanmohsin19/.torch/models/vgg19-dcbb9e9d.pth
# 574673361it [00:08, 70978402.12it/s]

# %%
path = "/home/hasanmohsin19/layers_epoch_300"
net_v = load_state_from_dc(net_v, "layers_epoch_300")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-78-57701f0c9b54> in <module>
#       1 path = "/home/hasanmohsin19/layers_epoch_300"
# ----> 2 net_v = load_state_from_dc(net_v, "layers_epoch_300")
#
# ~/saving_pretrain.py in load_state_from_dc(model, dc_path)
#      24     new_model_dict = update_dc_state(model.state_dict(), dc_state)
#      25
# ---> 26     model.load_state_dict(new_model_dict)
#      27
#      28     return model
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#     767         if len(error_msgs) > 0:
#     768             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# --> 769                                self.__class__.__name__, "\n\t".join(error_msgs)))
#     770
# ...

# %%
sta = torch.load("resnet50-p_weights")

# %%
for name, param in sta.items():
    print(name)
# Out:
# res.0.weight
# res.1.weight
# res.1.bias
# res.1.running_mean
# res.1.running_var
# res.1.num_batches_tracked
# res.4.0.conv1.weight
# res.4.0.bn1.weight
# res.4.0.bn1.bias
# res.4.0.bn1.running_mean
# res.4.0.bn1.running_var
# res.4.0.bn1.num_batches_tracked
# res.4.0.conv2.weight
# res.4.0.bn2.weight
# res.4.0.bn2.bias
# res.4.0.bn2.running_mean
# res.4.0.bn2.running_var
# res.4.0.bn2.num_batches_tracked
# res.4.0.conv3.weight
# res.4.0.bn3.weight
# res.4.0.bn3.bias
# res.4.0.bn3.running_mean
# res.4.0.bn3.running_var
# res.4.0.bn3.num_batches_tracked
# res.4.0.downsample.0.weight
# res.4.0.downsample.1.weight
# res.4.0.downsample.1.bias
# res.4.0.downsample.1.running_mean
# res.4.0.downsample.1.running_var
# res.4.0.downsample.1.num_batches_tracked
# res.4.1.conv1.weight
# res.4.1.bn1.weight
# res.4.1.bn1.bias
# res.4.1.bn1.running_mean
# res.4.1.bn1.running_var
# res.4.1.bn1.num_batches_tracked
# res.4.1.conv2.weight
# res.4.1.bn2.weight
# res.4.1.bn2.bias
# ...
